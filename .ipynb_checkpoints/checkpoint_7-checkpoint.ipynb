# %% [markdown]
# # Prédiction de la survie des passagers du titanic

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(0)

# %% [raw]
# Preprocessing

# %%
data = pd.read_csv(r'C:\Users\IDEAPAD\Desktop\GOMYCODE\SML\Titanic Forest\Resources\titanic-passengers.csv')
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander  Mr. Erik Gustaf
# 1           76       No       3                      Moen  Mr. Sigurd Hansen
# 2          641       No       3                       Jensen  Mr. Hans Peder
# 3          568       No       3  Palsson  Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson  Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data = data.drop(['PassengerId', 'Name', 'Cabin', 'Ticket', 'Embarked'], axis = 1)#Suppression des colonnes jugées inutiles
data = data.dropna(axis=0) # Suppression des ligne contenant des valeurs nulles
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64

# %%
data.shape
# Out:
# (714, 7)

# %%
data.head()
# Out:
#   Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0       No       2    male  28.0      0      0  13.0000
# 1       No       3    male  25.0      0      0   7.6500
# 2       No       3    male  20.0      0      0   7.8542
# 3       No       3  female  29.0      0      4  21.0750
# 4       No       1    male  31.0      1      0  52.0000

# %%
#Transfom Cat data to Num data
encoder = LabelEncoder()
data['Survived'] = encoder.fit_transform(data['Survived']) # Yes : 1 , No : 0
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       2    male  28.0      0      0  13.0000
# 1         0       3    male  25.0      0      0   7.6500
# 2         0       3    male  20.0      0      0   7.8542
# 3         0       3  female  29.0      0      4  21.0750
# 4         0       1    male  31.0      1      0  52.0000

# %% [raw]
# Visualisation

# %%
#Corrélation entre l'age et le sexe dans la survie de l'individu
sns.set_theme(style="whitegrid")

survived = 'survived'
not_survived = 'not survived'
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
women = data[data['Sex']== 'female'] #DF contenant seulement les femmes 
men = data[data['Sex']== 'male'] #DF contenant seulement les hommmes 

ax = sns.histplot(women[women['Survived']==1].Age, bins=18, label = survived, ax = axes[0], kde =False, color='Green')
ax = sns.histplot(women[women['Survived']==0].Age, bins=40, label = not_survived, ax = axes[0], kde =False, color='Red')
ax.legend()
ax.set_title('Femme')

ax = sns.histplot(men[men['Survived']==1].Age, bins=18, label = survived, ax = axes[1], kde = False, color='Green')
ax = sns.histplot(men[men['Survived']==0].Age, bins=40, label = not_survived, ax = axes[1], kde = False, color='Red')
ax.legend()
ax.set_title('Homme')
# Out:
# Text(0.5, 1.0, 'Homme')

# %%
#Importance de la classe dans la survie de l'individu
sns.barplot(x='Pclass', y='Survived', data=data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.histplot(data, x="Sex") # Plus d'homme que de femmes
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(data, x="Pclass", hue='Sex', multiple="dodge") #Plus d'hommes dans la 3ème classe qui a compté le moins de survivant
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %%
#Connaître le nombre d'enfant
def titanic_children(passenger):
    age , sex = passenger
    if age < 16:
        return 'child'
    else:
        return sex

data['Person'] = data[['Age', 'Sex']].apply(titanic_children,axis=1)
data.tail()
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Person
# 885         0       2    male  42.0      0      0  13.0000    male
# 886         1       2  female  14.0      1      0  30.0708   child
# 887         0       3    male  22.0      0      0   7.2292    male
# 888         0       3  female  30.0      0      0   8.6625  female
# 890         1       2  female  19.0      0      0  26.0000  female

# %%
sns.histplot(data, x="Pclass", hue='Person', multiple="dodge")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %%
#Vérifier qu'un passager à de la famille ou pas
#SibSp : Nombre de Frères et Soeurs et Parch : Nombre de Parents à bord du Titanic
data['Alone'] = data['SibSp'] + data['Parch']
data['Alone'].loc[data['Alone'] > 0] = 'Has a family'
data['Alone'].loc[data['Alone'] == 0] = 'Has no family'
data.tail()
# Out:
# C:\Users\IDEAPAD\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Person  \
# 885         0       2    male  42.0      0      0  13.0000    male
# 886         1       2  female  14.0      1      0  30.0708   child
# 887         0       3    male  22.0      0      0   7.2292    male
# 888         0       3  female  30.0      0      0   8.6625  female
# 890         1       2  female  19.0      0      0  26.0000  female
#
#              Alone
# 885  Has no family
# 886   Has a family
# 887  Has no family
# 888  Has no family
# 890  Has no family

# %%
#Conversion des Data Catégorielles en Data Numériques
data['Sex'] = encoder.fit_transform(data['Sex']) # Male : 1 , Female : 0
data['Person'] = encoder.fit_transform(data['Person']) # Male :2 , Female : 1 , Child : 0
data['Alone'] = encoder.fit_transform(data['Alone']) # Has no Family : 1, has Family : 0

# %%
#Séparation de nos données
X = data.drop(['Survived'],axis=1)
Y = data['Survived']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=40)

# %% [markdown]
# # Arbre de Décision

# %%
model_tree = DecisionTreeClassifier()
model_tree.fit(x_train, y_train)
y_pred = model_tree.predict(x_test)
print((" Accuracy : {} %").format(accuracy_score(y_test, y_pred) * 100))
# Out:
#  Accuracy : 85.3146853146853 %

# %%
#Tracé de l'arbre
fig = plt.figure(figsize=(25, 20))
_ = tree.plot_tree(model_tree, filled=True)

# %% [raw]
# Interprétation : L'arbre est beaucoup trop grand et donc difficile à interpréter maunellement. Cepenedant, nous obtenons une Accuracy de 85% en utilisaant la fonction accuracy_score()

# %%
#Modification des paramètres de l'arbre
model_tree = DecisionTreeClassifier(criterion='gini', splitter='random', max_leaf_nodes=10, min_samples_leaf=5, max_depth=5)
model_tree.fit(x_train, y_train)
y_pred = model_tree.predict(x_test)
print(("Accuracy : {} % ").format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy : 86.7132867132867 %

# %%
#Tracé de l'arbre
fig = plt.figure(figsize=(25, 20))
_ = tree.plot_tree(model_tree, feature_names=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Person', 'Alone'] ,filled=True)

# %% [raw]
# Interprétation : En modifiant, les paramètres de l'arbre de décision, on obtient une Accuracy plus élévée que la précédente qui est de 86%

# %% [markdown]
# # Random Forest

# %%
clf = RandomForestClassifier(n_estimators=10)
clf.fit(x_train, y_train)
pred = clf.predict(x_test)

confusion_matrix = pd.crosstab(y_test, pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
print(classification_report(y_test, pred)) # Accuracy = 87%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        85
#            1       0.90      0.76      0.82        58
#
#     accuracy                           0.87       143
#    macro avg       0.87      0.85      0.86       143
# weighted avg       0.87      0.87      0.86       143

# %% [raw]
# Interprétation : Le Random Forest permet d'accroître la précision qui est passée de 86% à 87%
